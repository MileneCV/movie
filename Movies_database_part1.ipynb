# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import os, time,json
import tmdbsimple as tmdb 
from tqdm.notebook import tqdm_notebook
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Downloading the Files

# %%
# Install tmdbsimple (only need to run once)
# !pip install tmdbsimple
# Out:
# Requirement already satisfied: tmdbsimple in k:\coding_dojo\anaconda\envs\dojo-env\lib\site-packages (2.9.1)
# Requirement already satisfied: requests in k:\coding_dojo\anaconda\envs\dojo-env\lib\site-packages (from tmdbsimple) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in k:\coding_dojo\anaconda\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in k:\coding_dojo\anaconda\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in k:\coding_dojo\anaconda\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in k:\coding_dojo\anaconda\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (1.26.13)

# %%
basics_url = 'https://datasets.imdbws.com/title.basics.tsv.gz'
akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'
ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %% [markdown]
# # Loading TSV's with Pandas

# %%
basics = pd.read_csv(basics_url, sep = '\t', low_memory = False)
basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9490669  tt9916848  tvEpisode              Episode #3.17
# 9490670  tt9916850  tvEpisode              Episode #3.19
# 9490671  tt9916852  tvEpisode              Episode #3.20
# 9490672  tt9916856      short                   The Wind
# 9490673  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# 2                   Pauvre Pierrot       0      1892      \N              4
# 3                      Un bon bock       0      1892      \N             12
# 4                 Blacksmith Scene       0      1893      \N              1
# ...                            ...     ...       ...     ...            ...
# 9490669              Episode #3.17       0      2010      \N             \N
# 9490670              Episode #3.19       0      2010      \N             \N
# 9490671              Episode #3.20       0      2010      \N             \N
# 9490672                   The Wind       0      2015      \N             27
# 9490673  Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9490669         Action,Drama,Family
# 9490670         Action,Drama,Family
# 9490671         Action,Drama,Family
# 9490672                       Short
# 9490673  Adventure,Animation,Comedy
#
# [9490674 rows x 9 columns]

# %%
akas = pd.read_csv(akas_url, sep = '\t', low_memory = False)
akas
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 34388480  tt9916852         5             Episódio #3.20     PT       pt
# 34388481  tt9916852         6             Episodio #3.20     IT       it
# 34388482  tt9916852         7               एपिसोड #3.20     IN       hi
# 34388483  tt9916856         1                   The Wind     DE       \N
# 34388484  tt9916856         2                   The Wind     \N       \N
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay             \N               0
# 1                  \N  literal title               0
# 2         imdbDisplay             \N               0
# 3         imdbDisplay             \N               0
# 4         imdbDisplay             \N               0
# ...               ...            ...             ...
# 34388480           \N             \N               0
# 34388481           \N             \N               0
# 34388482           \N             \N               0
# 34388483  imdbDisplay             \N               0
# 34388484     original             \N               1
#
# [34388485 rows x 8 columns]

# %%
ratings = pd.read_csv(ratings_url, sep = '\t', low_memory = False)
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1930
# 1        tt0000002            5.8       261
# 2        tt0000003            6.5      1750
# 3        tt0000004            5.6       176
# 4        tt0000005            6.2      2562
# ...            ...            ...       ...
# 1262150  tt9916682            6.4         6
# 1262151  tt9916690            7.8         7
# 1262152  tt9916730            8.0         8
# 1262153  tt9916766            7.0        21
# 1262154  tt9916778            7.2        36
#
# [1262155 rows x 3 columns]

# %% [markdown]
# # Filtering/Cleaning Steps:

# %% [markdown]
# ## Replace "\N" with np.nan

# %%
basics= basics.replace({'\\N':np.nan})
akas = akas.replace({'\\N':np.nan})
ratings =ratings.replace({'\\N':np.nan})

# %%
# check nan values
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1273306
# endYear           9390003
# runtimeMinutes    6743241
# genres             433537
# dtype: int64

# %%
# check duplicates
basics.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Eliminate movies that are null for runtimeMinutes and genres

# %%
#Eliminate movies that are null for runtimeMinutes and genre
basics = basics.dropna(subset=['runtimeMinutes', 'genres'])

# %%
#check nan values 
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            1
# originalTitle           1
# isAdult                 0
# startYear          145049
# endYear           2624702
# runtimeMinutes          0
# genres                  0
# dtype: int64

# %% [markdown]
# ## keep only titleType==Movie

# %%
# check type
basics['titleType'].value_counts()
# Out:
# tvEpisode       1311304
# short            586872
# movie            374333
# video            177858
# tvMovie           90384
# tvSeries          88510
# tvSpecial         17360
# tvMiniSeries      16648
# tvShort            8589
# videoGame           312
# Name: titleType, dtype: int64

# %%
# keep only titleType==Movie
basics = basics.loc[basics['titleType'] == 'movie']
# check type
basics['titleType'].value_counts()
# Out:
# movie    374333
# Name: titleType, dtype: int64

# %% [markdown]
# ## keep startYear 2000-2022

# %%
# check startYear
basics['startYear'].value_counts()
# Out:
# 2017    14260
# 2018    14208
# 2019    13904
# 2016    13884
# 2015    13394
#         ...
# 1899        1
# 1904        1
# 1897        1
# 1896        1
# 1894        1
# Name: startYear, Length: 127, dtype: int64

# %%
# check dtype
basics['startYear'].dtype
# Out:
# dtype('O')

# %%
# we need to change to integer to filter 2000-2021 but first drop nan
basics = basics.dropna(subset=['startYear'])

# %%
# change to integer
basics['startYear'] = basics['startYear'].astype(int)
# check
basics['startYear'].dtype
# Out:
# dtype('int32')

# %%
# filter startYear 2000-2022
basics = basics[(basics['startYear'] >=2000) & (basics['startYear'] <=2022)]
# Check 
basics['startYear'].value_counts()
# Out:
# 2017    14260
# 2018    14208
# 2019    13904
# 2016    13884
# 2015    13394
# 2014    13021
# 2013    12323
# 2021    12046
# 2022    11833
# 2012    11581
# 2020    11393
# 2011    10731
# 2010    10157
# 2009     9313
# 2008     8109
# 2007     6921
# 2006     6462
# 2005     5785
# 2004     5161
# 2003     4549
# 2002     4106
# 2001     3825
# 2000     3611
# Name: startYear, dtype: int64

# %% [markdown]
# ## Eliminate movies that include "Documentary"

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %% [markdown]
# ## Keep only US movies

# %%
akas = akas[(akas['region'] == 'US')]
# check
akas['region'].value_counts()
# Out:
# US    1400595
# Name: region, dtype: int64

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9489811  tt9914942     movie
# 9490207  tt9915872     movie
# 9490347  tt9916170     movie
# 9490356  tt9916190     movie
# 9490440  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9489811                             Life Without Sara Amat
# 9490207                               The Last White Witch
# 9490347                                      The Rehearsal
# 9490356                                          Safeguard
# 9490440                                              Coven
#
#                                      originalTitle isAdult  startYear endYear  \
# 34803                               Kate & Leopold       0       2001     NaN
# 61116    El Tango del Viudo y Su Espejo Deformante       0       2020     NaN
# 67669                   The Other Side of the Wind       0       2018     NaN
# 86801                            The Naked Monster       0       2005     NaN
# 93938                         Crime and Punishment       0       2002     NaN
# ...                                            ...     ...        ...     ...
# 9489811                 La vida sense la Sara Amat       0       2019     NaN
# 9490207                  My Girlfriend is a Wizard       0       2019     NaN
# 9490347                                   O Ensaio       0       2019     NaN
# 9490356                                  Safeguard       0       2020     NaN
# 9490440                                   Akelarre       0       2020     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 86801              100       Comedy,Horror,Sci-Fi
# 93938              126                      Drama
# ...                ...                        ...
# 9489811             74                      Drama
# 9490207             97       Comedy,Drama,Fantasy
# 9490347             51                      Drama
# 9490356             95  Action,Adventure,Thriller
# 9490440             92              Drama,History
#
# [84348 rows x 9 columns]

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers1 =ratings['tconst'].isin(akas['titleId'])
ratings = ratings[keepers1]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1930
# 1        tt0000002            5.8       261
# 4        tt0000005            6.2      2562
# 5        tt0000006            5.1       176
# 6        tt0000007            5.4       805
# ...            ...            ...       ...
# 1262129  tt9916200            8.2       220
# 1262130  tt9916204            8.2       251
# 1262136  tt9916348            8.5        17
# 1262137  tt9916362            6.4      5087
# 1262141  tt9916428            3.8        14
#
# [482688 rows x 3 columns]

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 482688 entries, 0 to 1262141
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         482688 non-null  object
#  1   averageRating  482688 non-null  float64
#  2   numVotes       482688 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 14.7+ MB

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1400595 entries, 5 to 34388229
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1400595 non-null  object
#  1   ordering         1400595 non-null  int64
#  2   title            1400595 non-null  object
#  3   region           1400595 non-null  object
#  4   language         3758 non-null     object
#  5   types            968632 non-null   object
#  6   attributes       45613 non-null    object
#  7   isOriginalTitle  1399250 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 96.2+ MB

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84348 entries, 34803 to 9490440
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          84348 non-null  object
#  1   titleType       84348 non-null  object
#  2   primaryTitle    84348 non-null  object
#  3   originalTitle   84348 non-null  object
#  4   isAdult         84348 non-null  object
#  5   startYear       84348 non-null  int32
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  84348 non-null  object
#  8   genres          84348 non-null  object
# dtypes: int32(1), object(8)
# memory usage: 6.1+ MB

# %%
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9489811  tt9914942     movie
# 9490207  tt9915872     movie
# 9490347  tt9916170     movie
# 9490356  tt9916190     movie
# 9490440  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9489811                             Life Without Sara Amat
# 9490207                               The Last White Witch
# 9490347                                      The Rehearsal
# 9490356                                          Safeguard
# 9490440                                              Coven
#
#                                      originalTitle isAdult  startYear endYear  \
# 34803                               Kate & Leopold       0       2001     NaN
# 61116    El Tango del Viudo y Su Espejo Deformante       0       2020     NaN
# 67669                   The Other Side of the Wind       0       2018     NaN
# 86801                            The Naked Monster       0       2005     NaN
# 93938                         Crime and Punishment       0       2002     NaN
# ...                                            ...     ...        ...     ...
# 9489811                 La vida sense la Sara Amat       0       2019     NaN
# 9490207                  My Girlfriend is a Wizard       0       2019     NaN
# 9490347                                   O Ensaio       0       2019     NaN
# 9490356                                  Safeguard       0       2020     NaN
# 9490440                                   Akelarre       0       2020     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 86801              100       Comedy,Horror,Sci-Fi
# 93938              126                      Drama
# ...                ...                        ...
# 9489811             74                      Drama
# 9490207             97       Comedy,Drama,Fantasy
# 9490347             51                      Drama
# 9490356             95  Action,Adventure,Thriller
# 9490440             92              Drama,History
#
# [84348 rows x 9 columns]

# %%
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 34388012  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 34388082  tt9916620         1                          The Copeland Case
# 34388170  tt9916702         1              Loving London: The Playground
# 34388213  tt9916756         1                   Pretty Pretty Black Girl
# 34388229  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 34388012     US      NaN  imdbDisplay                    NaN               0
# 34388082     US      NaN          NaN                    NaN               0
# 34388170     US      NaN          NaN                    NaN               0
# 34388213     US      NaN  imdbDisplay                    NaN               0
# 34388229     US      NaN  imdbDisplay                    NaN               0
#
# [1400595 rows x 8 columns]

# %%
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1930
# 1        tt0000002            5.8       261
# 4        tt0000005            6.2      2562
# 5        tt0000006            5.1       176
# 6        tt0000007            5.4       805
# ...            ...            ...       ...
# 1262129  tt9916200            8.2       220
# 1262130  tt9916204            8.2       251
# 1262136  tt9916348            8.5        17
# 1262137  tt9916362            6.4      5087
# 1262141  tt9916428            3.8        14
#
# [482688 rows x 3 columns]

# %% [markdown]
# ## Saving the Files in Your Repository

# %%
# making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# []

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
rating = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
rating.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1930
# 1  tt0000002            5.8       261
# 2  tt0000005            6.2      2562
# 3  tt0000006            5.1       176
# 4  tt0000007            5.4       805
